# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## __Objectives:__
# + List the popular languages used in Data Science
# + List the commonly used libraries in Data Science
# + Show an example of simple arithmetics in Python, such as:
#     * Adition
#     * Substraction
#     * Division

# %% [markdown]
# ## Author
# Alejandro Arze

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# Data Science Tools |
# --- |
# RStudio |
# JupyterLab |
# Anaconda |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
x=30
y=15
sum_result = x + y
dif_result = x - y
div_result = x/y
print(f"Addition: {x} + {y} = {sum_result}")
print(f"Substraction: {x} - {y} = {dif_result}")
print(f"Division: {x} / {y} = {div_result}")
# Out:
# Addition: 30 + 15 = 45
# Substraction: 30 - 15 = 15
# Division: 30 / 15 = 2.0

# %%
# This a simple arithmetic expression to mutiply then add integers
result=(3*4)+5
print(result)
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
m = 200
h = 200/60
print(h)
# Out:
# 3.3333333333333335
